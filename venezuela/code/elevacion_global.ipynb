# %% [markdown]
# ## Visualización de la elevación
#
# **PROYECTO:** SISTEMA PARA EL SEGUIMIENTO DE ECOSISTEMAS VENEZOLANOS \
# **AUTOR:** Javier Martinez

# %%
import os

import rioxarray 
from rioxarray.merge import merge_datasets
import xarray
from shapely.geometry import (Polygon, mapping)
import geopandas

import pandas as pd
from datetime import datetime
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.pylab as pylab

# %% [markdown]
# Directorio de trabajo

# %%
print('> Directorio actual: ', os.getcwd())  
os.chdir('../')
os.chdir('../')
print('> Directorio actual: ', os.getcwd())
# Out:
# > Directorio actual:  /media/javier/Compartida/doctorado/gee-metview/venezuela/code
# > Directorio actual:  /media/javier/Compartida/doctorado/gee-metview

# %% [markdown]
# ### Clase para apertura de objetos

# %%
# Crewacion del objeto xarray
def create_dataset(da, band_name = 'variable',crs='4326'):
  """
  Funcion para la creacion del dataset
  """

  ds = xarray.Dataset({
          band_name : xarray.DataArray(
                      data = da.data,
                      dims = ['band','y','x'],
                      coords = {'band':da['band'].data,'y': da['y'].data, 'x': da['x'].data},
                      attrs = da.attrs
                      )
            },
      attrs = da.attrs
      )

  ds = ds.rio.write_crs(crs)

  return ds

# %% [markdown]
# ### Cargando archivos

# %%
  path_elevacion = './SRTMGL3/files/'
  elevacion_files = list(map(lambda x: path_elevacion + x, os.listdir(path_elevacion) ))
  elevacion_files
# Out:
# ['./SRTMGL3/files/N09W069.hgt',
#  './SRTMGL3/files/N09W070.hgt',
#  './SRTMGL3/files/N09W071.hgt',
#  './SRTMGL3/files/N09W072.hgt',
#  './SRTMGL3/files/N10W069.hgt',
#  './SRTMGL3/files/N10W070.hgt',
#  './SRTMGL3/files/N10W071.hgt',
#  './SRTMGL3/files/N10W072.hgt',
#  './SRTMGL3/files/N11W069.hgt',
#  './SRTMGL3/files/N11W070.hgt',
#  './SRTMGL3/files/N11W071.hgt',
#  './SRTMGL3/files/N11W072.hgt']

# %%
import warnings
warnings.filterwarnings("ignore")


data_file = list(map(lambda x: xarray.open_rasterio(x), elevacion_files))

# %%
crs_elevacion = data_file[0].rio.crs
# Out:
# Warning 1: +init=epsg:XXXX syntax is deprecated. It might return a CRS with a non-EPSG compliant axis order.

# %%
data_format = list(map(lambda x: create_dataset(x, 'elevacion',crs=crs_elevacion), data_file))

# %%
rds_elevacion = merge_datasets(data_format)

# %%
rds_elevacion.rio.crs
# Out:
# CRS.from_wkt('GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Longitude",EAST],AXIS["Latitude",NORTH]]')

# %%
rds_elevacion
# Out:
# <xarray.Dataset>
# Dimensions:      (band: 1, y: 3601, x: 4801)
# Coordinates:
#   * band         (band) int64 1
#   * x            (x) float64 -72.0 -72.0 -72.0 -72.0 ... -68.0 -68.0 -68.0 -68.0
#   * y            (y) float64 12.0 12.0 12.0 12.0 12.0 ... 9.002 9.002 9.001 9.0
#     spatial_ref  int64 0
# Data variables:
#     elevacion    (band, y, x) int16 41 43 43 42 44 45 45 ... 77 82 80 81 77 74
# Attributes:
#     transform:   (0.0008333333333333334, 0.0, -69.00041666666667, 0.0, -0.000...
#     res:         (0.0008333333333333334, 0.0008333333333333334)
#     is_tiled:    0
#     nodatavals:  (-32768.0,)
#     scales:      (1.0,)
#     offsets:     (0.0,)
#     units:       ('m',)

# %% [markdown]
# #### Generando Gráfico

# %%
venezuela_poligonos = geopandas.read_file('./venezuela/polygons/venezuela.shp')
venezuela_poligonos = venezuela_poligonos.to_crs(rds_elevacion.rio.crs)
venezuela_poligonos.crs
# Out:
# <Geographic 2D CRS: GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84" ...>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - lon[east]: Longitude (degree)
# - lat[north]: Latitude (degree)
# Area of Use:
# - undefined
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
venezuela_poligonos
# Out:
#     ID_0  ISO     NAME_0  ID_1                  NAME_1  \
# 0    249  VEN  Venezuela     1                Amazonas
# 1    249  VEN  Venezuela     2              Anzoátegui
# 2    249  VEN  Venezuela     3                   Apure
# 3    249  VEN  Venezuela     4                  Aragua
# 4    249  VEN  Venezuela     5                 Barinas
# 5    249  VEN  Venezuela     6                 Bolívar
# 6    249  VEN  Venezuela     7                Carabobo
# 7    249  VEN  Venezuela     8                 Cojedes
# 8    249  VEN  Venezuela     9           Delta Amacuro
# 9    249  VEN  Venezuela    10  Dependencias Federales
# 10   249  VEN  Venezuela    11        Distrito Capital
# 11   249  VEN  Venezuela    12                  Falcón
# 12   249  VEN  Venezuela    13                 Guárico
# 13   249  VEN  Venezuela    14                    Lara
# 14   249  VEN  Venezuela    15                  Mérida
# 15   249  VEN  Venezuela    16                 Miranda
# 16   249  VEN  Venezuela    17                 Monagas
# 17   249  VEN  Venezuela    18           Nueva Esparta
# 18   249  VEN  Venezuela    19              Portuguesa
# 19   249  VEN  Venezuela    20                   Sucre
# 20   249  VEN  Venezuela    21                 Táchira
# 21   249  VEN  Venezuela    22                Trujillo
# 22   249  VEN  Venezuela    23                  Vargas
# 23   249  VEN  Venezuela    24                 Yaracuy
# 24   249  VEN  Venezuela    25                   Zulia
#
#                     TYPE_1           ENGTYPE_1 NL_NAME_1 VARNAME_1  \
# 0                     None                None      None      None
# 1                     None                None      None      None
# 2                     None                None      None      None
# 3                     None                None      None      None
# 4                     None                None      None      None
# 5                     None                None      None      None
# 6                     None                None      None      None
# 7                     None                None      None      None
# 8                     None                None      None      None
# 9   Dependencias Federales  Federal Dependency      None      None
# 10                    None                None      None      None
# 11                    None                None      None      None
# 12                    None                None      None      None
# 13                    None                None      None      None
# 14                    None                None      None      None
# 15                    None                None      None      None
# 16                    None                None      None      None
# 17                    None                None      None      None
# 18                    None                None      None      None
# 19                    None                None      None      None
# 20                    None                None      None      None
# 21                    None                None      None      None
# 22                    None                None      None      None
# 23                    None                None      None      None
# 24                    None                None      None      None
#
#                                              geometry
# 0   POLYGON ((-64.63861 4.16460, -64.65859 4.21149...
# 1   MULTIPOLYGON (((-64.93488 10.15512, -64.92551 ...
# 2   POLYGON ((-67.51847 7.84824, -67.50046 7.84845...
# 3   POLYGON ((-67.36453 10.53827, -67.35392 10.502...
# 4   POLYGON ((-70.19752 9.04690, -70.18346 9.03049...
# 5   POLYGON ((-60.14613 7.98914, -60.16044 7.98283...
# 6   POLYGON ((-68.24053 10.58348, -68.22203 10.559...
# 7   POLYGON ((-67.80265 9.85504, -67.79624 9.85315...
# 8   MULTIPOLYGON (((-60.64272 8.68394, -60.63482 8...
# 9   MULTIPOLYGON (((-67.67067 11.98822, -67.66253 ...
# 10  POLYGON ((-67.12771 10.44722, -67.11340 10.457...
# 11  MULTIPOLYGON (((-68.23855 10.83205, -68.25163 ...
# 12  POLYGON ((-65.72676 9.96775, -65.72182 9.94799...
# 13  POLYGON ((-68.86737 10.70776, -68.86712 10.699...
# 14  POLYGON ((-70.54042 8.99874, -70.54979 8.99159...
# 15  POLYGON ((-65.38854 10.12989, -65.40088 10.112...
# 16  MULTIPOLYGON (((-62.43739 10.05208, -62.42925 ...
# 17  MULTIPOLYGON (((-63.99302 10.81712, -63.98710 ...
# 18  POLYGON ((-68.97492 9.79132, -68.95223 9.76672...
# 19  MULTIPOLYGON (((-64.40203 10.37256, -64.39759 ...
# 20  POLYGON ((-71.50029 7.62134, -71.50967 7.59821...
# 21  POLYGON ((-70.01916 9.47589, -70.02879 9.46663...
# 22  POLYGON ((-67.36453 10.53827, -67.35269 10.540...
# 23  POLYGON ((-68.26618 10.62239, -68.25089 10.597...
# 24  MULTIPOLYGON (((-71.19341 9.22543, -71.18404 9...

# %%
venezuela_estados = venezuela_poligonos[venezuela_poligonos.NAME_1.isin(['Barinas','Mérida','Falcón','Zulia','Trujillo','Carabobo','Yaracuy','Lara','Portuguesa','Cojedes'])]
venezuela_estados.boundary.plot(color='#001B32', linewidth=1)
# Out:
# <AxesSubplot:>

# %%
# plot
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(1, 1, 1)

# Raster
levels=[200,300,400,500,600,700,800,900,1000,1100,1200,1300,1400]
graf = rds_elevacion.elevacion.plot(cmap='Purples',levels=levels)
graf.colorbar.set_label('Elevación (m)',fontsize=18)
ax.add_collection(graf)

# poligonos
venezuela_estados.boundary.plot(color='#001B32', linewidth=1,ax=ax)

# titulos
plt.title(f"",fontsize=30,loc='center')
plt.suptitle("Producto SRTMGL3",ha='left',fontsize=30, x=.25)
plt.xlabel("Longitud",loc='center',fontsize=18)
plt.ylabel("Latitud",loc='center',fontsize=18)

plt.savefig('./venezuela/figures/nasa_elevacion.png')

plt.show()
